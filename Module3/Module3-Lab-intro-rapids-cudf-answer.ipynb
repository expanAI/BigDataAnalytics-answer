# %% [markdown]
# # Introduction to RAPIDS

# %% [markdown]
# The RAPIDS data science framework is a GPU-empowered collection of libraries for executing end-to-end data science pipelines completely in the GPU. It is designed to make an effective use of the computational capabilities of GPUs with optimized NVIDIA CUDA® primitives and high-bandwidth GPU memory. The primary objective behind using RAPIDS is to accelerate individual parts of the typical data science workflow, and thereby accelerating the complete end-to-end workflow in Data Preparation and Machine Learning.
#
# Read through [this](https://medium.com/future-vision/what-is-rapids-ai-7e552d80a1d2) medium article to understand how RAPIDS works.
# <br><br>
# If you have already worked with pandas and numpy previously, most of the tutorial will seem very familiar to you. If you haven't, do not worry. This is a great place to start!

# %% [markdown]
# ## SETUP
#
# **Note that pandas is a data analysis and manipulation tool built on top of the Python programming language to perform various tasks (e.g.: loading, joining, aggregating, filtering data). cuDF is a GPU DataFrame library that helps perform similar functionalities with massive acceleration.**

# %%
import cudf
import pandas as pd

# %% [markdown]
# Before we dive in, please make sure to check out the official documentation [here](https://docs.rapids.ai/api) to get an overall idea. Additionally, refer to the [cheatsheet](https://rapids.ai/assets/files/cheatsheet.pdf) for a crisp and clear representation of the functionalities provided by RAPIDS.

# %% [markdown]
# ## SECTION 1: CUDF BASICS
# ### cuDF DataFrame
# Firstly, we will understand creating dataframes in cuDF. You can build a dataframe in multiple ways as shown in the official documentation. Let us first initialize the dataframe object.

# %%
gdf = cudf.DataFrame()

# %% [markdown]
# Now that we have a cudf.Dataframe object, we will build the dataframe with values. Let us explore adding values by defining them through their columns.

# %%
#creates a column named 'index' with the values 0, 1, 2, 3, 4
gdf['index'] = [0, 1, 2, 3, 4]

#creates a column named 'value' with the values 10, 20, 30, 40, 50
gdf['value'] = [10, 20, 30, 40, 50]

#displays the current cudf dataframe
gdf
# Out:
#    index  value
# 0      0     10
# 1      1     20
# 2      2     30
# 3      3     40
# 4      4     50

# %% [markdown]
# We can also build the dataframe with list of rows of the dataframe as tuples.

# %%
#the first parameter is the data and the second parameter is the name of the columns
df = cudf.DataFrame([
    (5, 60),
    (6, 70),
    (7, 80),
],
columns = ['index', 'value'])
df
# Out:
#    index  value
# 0      5     60
# 1      6     70
# 2      7     80

# %% [markdown]
# ## SECTION 2: CUDF using Netflix Movie Dataset
# Now that we have a basic understanding of how to work with a cuDF DataFrame, let us try to work with creating one from a dataset. We will be using the dataset from [here](https://www.kaggle.com/shivamb/netflix-shows) to get hands-on with cuDF.<br>

# %% [markdown]
# ### Reading a CSV file
# Import the netfilx_titles.csv dataset into a cuDF dataframe.

# %%
gdf = cudf.read_csv('/shared-data/Apr20/data/Module3/netflix_titles.csv')

# %% [markdown]
# ### Converting a Pandas DataFrame
# Alternatively, you could also read the data using Pandas and convert the dataframe to support cuDF functionalities.

# %%
#creates a pandas dataframe
pdf = pd.read_csv('/shared-data/Apr20/data/Module3/netflix_titles.csv')

#creates cudf dataframe from pandas dataframe
gdf = cudf.DataFrame.from_pandas(pdf)

#display dataframe
gdf
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                  None  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784               None                                            Nasty C
# 7785               None                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                               None
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                               None  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %% [markdown]
# Let us now delve into some questions on the dataset itself!

# %% [markdown]
# ### 1. Dropping columns
# __<span style="color:red">Exercise1:</span>__: This dataset has a lot of missing values primarily in the columns director and cast. Therefore, we will drop these two columns from our dataframe.
# Drop Display gdf after dropping to verify that the columns have been dropped

# %%
gdf.drop(columns=['director','cast'],inplace=True)
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                               None  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 10 columns]

# %% [markdown]
# ### 2. Missing values
# __<span style="color:red">Exercise2:</span>__: The dataset needs to be cleaned first. There are several NA values in the data that add no value, we can choose to drop these records. Create a clean dataframe with no NA values.
# Display gdf after dropping to verify that the NA values have been dropped

# %%
gdf=gdf.dropna()
gdf
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7781   s7782    Movie                                     Zoom
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                 country         date_added  \
# 0                                                Brazil    August 14, 2020
# 1                                                Mexico  December 23, 2016
# 2                                             Singapore  December 20, 2018
# 3                                         United States  November 16, 2017
# 4                                         United States    January 1, 2020
# ...                                                 ...                ...
# 7781                                      United States   January 11, 2020
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...   October 19, 2020
# 7783                                              India      March 2, 2019
# 7785                                          Australia   October 31, 2020
# 7786              United Kingdom, Canada, United States      March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7781          2006     PG     88 min
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7781                 Children & Family Movies, Comedies
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7781  Dragged from civilian life, a former superhero...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7265 rows x 10 columns]

# %% [markdown]
# ### 3. Querying DataFrame
# __<span style="color:red">Exercise3:</span>__: Find the shows that were released in the year 2011.

# %%
expr = "release_year==2011"
gdf.query(expr)
# Out:
#      show_id   type                     title        country  \
# 2         s3  Movie                     23:59      Singapore
# 104     s105  Movie        30 Minutes or Less  United States
# 122     s123  Movie                     50/50  United States
# 136     s137  Movie              7 Khoon Maaf          India
# 145     s146  Movie              A 2nd Chance      Australia
# ...      ...    ...                       ...            ...
# 7683   s7684  Movie                   X Large          Egypt
# 7695   s7696  Movie          Yaara O Dildaara          India
# 7736   s7737  Movie               Young Adult  United States
# 7769   s7770  Movie  Zindagi Na Milegi Dobara          India
# 7776   s7777  Movie                  Zokkomon          India
#
#              date_added  release_year rating duration  \
# 2     December 20, 2018          2011      R   78 min
# 104     January 1, 2021          2011      R   83 min
# 122        June 1, 2019          2011      R  100 min
# 136      August 2, 2018          2011  TV-MA  148 min
# 145        July 1, 2017          2011     PG   95 min
# ...                 ...           ...    ...      ...
# 7683       June 2, 2020          2011  TV-14  135 min
# 7695   November 1, 2017          2011  TV-14  132 min
# 7736  November 20, 2019          2011      R   94 min
# 7769  December 15, 2019          2011  TV-14  154 min
# 7776   November 1, 2018          2011     PG  104 min
#
#                                             listed_in  \
# 2                 Horror Movies, International Movies
# 104                      Action & Adventure, Comedies
# 122              Comedies, Dramas, Independent Movies
# 136           Dramas, International Movies, Thrillers
# 145   Children & Family Movies, Dramas, Sports Movies
# ...                                               ...
# 7683  Comedies, International Movies, Romantic Movies
# 7695   Dramas, International Movies, Music & Musicals
# 7736             Comedies, Dramas, Independent Movies
# 7769           Comedies, Dramas, International Movies
# 7776                 Children & Family Movies, Dramas
#
#                                             description
# 2     When an army recruit is found dead, his fellow...
# 104   Two crooks planning a bank heist wind up abduc...
# 122   An otherwise healthy twentysomething has a com...
# 136   Spiced liberally with black comedy, this Bolly...
# 145   A gymnast lacks the confidence she needs to re...
# ...                                                 ...
# 7683  After he is rejected by the woman he loves and...
# 7695  The patriarch of a wealthy family with one ind...
# 7736  When a divorced writer gets a letter from an o...
# 7769  Three friends on an adventurous road trip/bach...
# 7776  When his cruel uncle abandons him, a young orp...
#
# [163 rows x 10 columns]

# %% [markdown]
# ### 4. Sort values
# __<span style="color:red">Exercise4:</span>__: Sort the dataframe according to the year the record was released (latest first). Refer to sort_values function, which takes the target column name and the sorting mode

# %%
gdf.sort_values('release_year',ascending=False)
# Out:
#      show_id     type                                          title  \
# 1222   s1223  TV Show                                Carmen Sandiego
# 1285   s1286    Movie                                       Charming
# 1440   s1441  TV Show                                      Cobra Kai
# 1514   s1515    Movie        Crack: Cocaine, Corruption & Conspiracy
# 1780   s1781  TV Show                                 Disenchantment
# ...      ...      ...                                            ...
# 7342   s7343    Movie  Undercover: How to Operate Behind Enemy Lines
# 7616   s7617    Movie             Why We Fight: The Battle of Russia
# 7679   s7680    Movie                WWII: Report from the Aleutians
# 4960   s4961    Movie                                 Prelude to War
# 6117   s6118    Movie                           The Battle of Midway
#
#                                     country        date_added  release_year  \
# 1222                          United States  January 15, 2021          2021
# 1285  Canada, United States, Cayman Islands   January 8, 2021          2021
# 1440                          United States   January 1, 2021          2021
# 1514                          United States  January 11, 2021          2021
# 1780                          United States  January 15, 2021          2021
# ...                                     ...               ...           ...
# 7342                          United States    March 31, 2017          1943
# 7616                          United States    March 31, 2017          1943
# 7679                          United States    March 31, 2017          1943
# 4960                          United States    March 31, 2017          1942
# 6117                          United States    March 31, 2017          1942
#
#      rating   duration                                          listed_in  \
# 1222  TV-Y7  4 Seasons                             Kids' TV, TV Thrillers
# 1285  TV-Y7     85 min                 Children & Family Movies, Comedies
# 1440  TV-14  3 Seasons                   TV Action & Adventure, TV Dramas
# 1514  TV-MA     90 min                                      Documentaries
# 1780  TV-14  3 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# ...     ...        ...                                                ...
# 7342  TV-PG     61 min                      Classic Movies, Documentaries
# 7616  TV-PG     82 min                                      Documentaries
# 7679  TV-PG     45 min                                      Documentaries
# 4960  TV-14     52 min                      Classic Movies, Documentaries
# 6117  TV-14     18 min                      Classic Movies, Documentaries
#
#                                             description
# 1222  A master thief who uses her skills for good, C...
# 1285  On the eve of his 21st birthday, an adored pri...
# 1440  Decades after the tournament that changed thei...
# 1514  A cheap, powerful drug emerges during a recess...
# 1780  Princess duties call, but she'd rather be drin...
# ...                                                 ...
# 7342  This World War II-era training film dramatizes...
# 7616  This installment of Frank Capra's acclaimed do...
# 7679  Filmmaker John Huston narrates this Oscar-nomi...
# 4960  Frank Capra's documentary chronicles the rise ...
# 6117  Director John Ford captures combat footage of ...
#
# [7265 rows x 10 columns]

# %% [markdown]
# ### 5. GroupBy
# __<span style="color:red">Exercise5:</span>__: Alternatively, you can also find the number of movies and shows using a GroupBy and size.

# %%
gdf.groupby('type').count()
# Out:
#          show_id  title  country  date_added  release_year  rating  duration  \
# type
# Movie       5143   5143     5143        5143          5143    5143      5143
# TV Show     2122   2122     2122        2122          2122    2122      2122
#
#          listed_in  description
# type
# Movie         5143         5143
# TV Show       2122         2122
